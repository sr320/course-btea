# %%
# !pwd
# Out:
# /Users/sr320/git-repos/course-btea/day-2

# %%
ls
# Out:
# 00-better-downloads.ipynb       Geoduck-transcriptome-v2.fasta
# 01-Local_BLAST.ipynb            Geoduck_uniprot-conv
# Find-a-gene.ipynb               Geoduck_uniprot.out
# Geoducik-anno.csv               Untitled.ipynb
# Geoduck-blast.ipynb

# %%
# !head -1 Geoducik-anno.csv
# Out:
# Column1,Column2,Column3,Column4,Column5,Column6,Column7,Column8,Column9,Column10,Column11,Column12,Column13,Column14,Entry,Entry name,Gene ontology IDs,Interacts with,Cross-reference (GO),Gene ontology (GO),Status,InterPro,Pathway,Protein names,Gene names,Organism,Length

# %%
# !wc -l Geoducik-anno.csv
# Out:
#    11587 Geoducik-anno.csv

# %%
# !grep --color 'female' Geoducik-anno.csv
# Out:
# Pgenerosa-v1_contig_10266,sp,P15428,PGDH_HUMAN,38.22,259,153,3,1159,389,1,254,8E-58,197,P15428,PGDH_HUMAN,GO:0016404; GO:0070403; GO:0019371; GO:0005829; GO:0097070; GO:0007565; GO:2001300; GO:0019372; GO:0045786; GO:0005634; GO:0030728; GO:0007567; GO:0004957; GO:0042803; GO:0070493; GO:0007179,,,15-hydroxyprostaglandin dehydrogenase (NAD+) activity; NAD+ binding; cyclooxygenase pathway; cytosol; ductus arteriosus closure; female pregnancy; lipoxin metabolic process; lipoxygenase pathway; negative regulation of cell cycle; nucleus; ovulation; parturition; prostaglandin E receptor activity; protein homodimerization activity; thrombin receptor signaling pathway; transforming growth factor beta receptor signaling pathway,reviewed,IPR002198; IPR002347; IPR016040; IPR020904;,,15-hydroxyprostaglandin dehydrogenase [NAD(+)] (15-PGDH) (EC 1.1.1.141) (Prostaglandin dehydrogenase 1),HPGD PGDH1,Homo sapiens (Human),266
# ...
