# %% [markdown]
# #Olympia Oyster transcriptome

# %% [markdown]
# See Geoduck page for details on how to download and check integretity of raw files..

# %%
cd /Users/sr320/data-genomic/tentacle/OlyOv5
# Out:
# /Users/sr320/data-genomic/tentacle/OlyOv5

# %%
cd PE
# Out:
# /Users/sr320/data-genomic/tentacle/OlyOv5/PE

# %%
ls
# Out:
# filtered_106A_Female_Mix_GATCAG_L004_R1.fastq*    filtered_108A_Female_Mix_GGCTAC_L004_R1.fastq*
# filtered_106A_Female_Mix_GATCAG_L004_R1.fastq.gz* filtered_108A_Female_Mix_GGCTAC_L004_R1.fastq.gz*
# filtered_106A_Female_Mix_GATCAG_L004_R2.fastq*    filtered_108A_Female_Mix_GGCTAC_L004_R2.fastq*
# filtered_106A_Female_Mix_GATCAG_L004_R2.fastq.gz* filtered_108A_Female_Mix_GGCTAC_L004_R2.fastq.gz*
# filtered_106A_Male_Mix_TAGCTT_L004_R1.fastq*      filtered_108A_Male_Mix_AGTCAA_L004_R1.fastq*
# filtered_106A_Male_Mix_TAGCTT_L004_R1.fastq.gz*   filtered_108A_Male_Mix_AGTCAA_L004_R1.fastq.gz*
# filtered_106A_Male_Mix_TAGCTT_L004_R2.fastq*      filtered_108A_Male_Mix_AGTCAA_L004_R2.fastq*
# filtered_106A_Male_Mix_TAGCTT_L004_R2.fastq.gz*   filtered_108A_Male_Mix_AGTCAA_L004_R2.fastq.gz*

# %%
# !cat \
filtered_106A_Female_Mix_GATCAG_L004_R1.fastq \
filtered_108A_Female_Mix_GGCTAC_L004_R1.fastq \
filtered_106A_Male_Mix_TAGCTT_L004_R1.fastq \
filtered_108A_Male_Mix_AGTCAA_L004_R1.fastq >> /Users/sr320/data-genomic/tentacle/OlyOv6/OlyOv6_combined_R1.fastq
# !cat \
filtered_106A_Female_Mix_GATCAG_L004_R2.fastq \
filtered_108A_Female_Mix_GGCTAC_L004_R2.fastq \
filtered_106A_Male_Mix_TAGCTT_L004_R2.fastq \
filtered_108A_Male_Mix_AGTCAA_L004_R2.fastq >> /Users/sr320/data-genomic/tentacle/OlyOv6/OlyOv6_combined_R2.fastq

# %%
# !head R1.fastq

# %%
# !/Applications/bioinfo/trim_galore_zip/trim_galore \
--paired \
--retain_unpaired \
--path_to_cutadapt /Users/sr320/.local/bin/cutadapt \
R1.fastq \
R2.fastq
